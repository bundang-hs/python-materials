# %% [markdown]
# # 1. 파이썬 명령어 형식
# <img src='https://github.com/yeonjoo-teacher/images/blob/cf529267b368b385837f1d54717466c4a5f632f0/02_1.png?raw=true' width=400>

# %% [markdown]
# # 2. 출력명령어
# ### 출력 명령어 형식
#
#
# > print( 출력할 내용 )

# %%
#1 숫자 출력 1030

# %%
#2 문자 출력 10월 30일

# %% [markdown]
# ### 문자는 따옴표로 감싸주어야 함
# > print('문자')

# %%
# 문자는 따옴표로 감싸주어야 함. 10월 30일을 다시 출력해보시오.

# %%
#3 내 이름을 출력해보시오.

# %%
#4 숫자 연산을 출력해보시오.  (12+34, 12-34, 12*34, 12/34)

# %%
#5 숫자라 하더라도 따옴표로 감싸면 문자로 인식함.

# %% [markdown]
# ### 프로그래밍에서는 나머지값으로 홀수, 짝수 판별하는 문제가 많으므로 나머지 구하는 연산자 꼭 기억할 것!
# > 제곱(**), 몫(//), 나머지(%)

# %%
#6 12와 34로 제곱(**), 몫(//), 나머지(%) 출력하시오.

# %% [markdown]
# ### 연결하여 출력하기
# > print(  ,  )
# <br/>
# > print(  +  )

# %%
#7 콤마, 로 연결하여 파이썬 안녕! 출력하기

# %%
#8 더하기 +로 연결하여 파이썬 안녕! 출력하기

# %%
#9 학번과 이름을 +로 연결하여 출력하기

# %%
#10 학번과 이름을 ,로 연결하여 출력하기

# %% [markdown]
# 오류 발생 -> 숫자와 문자로 타입이 다를 경우에는 반드시 ,로 연결해서 출력해야함 :)

# %% [markdown]
# 🌱연습문제

# %%
#1. 저의 이름은 ㅇㅇㅇ입니다. 를 출력하시오.

# %%
#2. '저의 생일은', ㅇ, '월', ㅇ, '일 입니다.' 를 연결하여 출력하시오.
